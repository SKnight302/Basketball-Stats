# %%
import pandas as pd
df11 = pd.read_csv('./2011_csv_files/NCAA_2010-11_Completed_Stats.csv')
df12 = pd.read_csv('./2012_csv_files/NCAA_2011-12_Completed_Stats.csv')
df13 = pd.read_csv('./2013_csv_files/NCAA_2012-13_Completed_Stats.csv')
df14 = pd.read_csv('./2014_csv_files/NCAA_2013-14_Completed_Stats.csv')
df15 = pd.read_csv('./2015_csv_files/NCAA_2014-15_Completed_Stats.csv')
df16 = pd.read_csv('./2016_csv_files/NCAA_2015-16_Completed_Stats.csv')
df17 = pd.read_csv('./2017_csv_files/NCAA_2016-17_Completed_Stats.csv')
df18 = pd.read_csv('./2018_csv_files/NCAA_2017-18_Completed_Stats.csv')
df19 = pd.read_csv('./2019 csv_files/NCAA_C_Statistics_2018-19.csv')
df21 = pd.read_csv('./csv_files/NCAA 2020-21_Completed_Stats.csv')
df22 = pd.read_csv('./2022_csv_files/NCAA_2021-22_Completed_Stats.csv')

end_stats = pd.concat([df12,df11,df13,df14,df15,df16,df17,df18,df19,df21,df22])
end_stats
# Out:
#      Year                     Team  Power 5 School Placement Seed Berth type  \
# 0    2012           Kentucky (SEC)            True       1.0  1.0   At-large
# 1    2012         Murray St. (OVC)           False      32.0  6.0  Automatic
# 2    2012           Syracuse (AAC)           False       8.0  1.0   At-large
# 3    2012        Missouri (Big 12)            True      64.0  2.0  Automatic
# 4    2012     North Carolina (ACC)            True       8.0  1.0   At-large
# ..    ...                      ...             ...       ...  ...        ...
# 345  2022          IUPUI (Horizon)           False       DNP  DNP        DNP
# 346  2022      Oregon St. (Pac-12)            True       DNP  DNP        DNP
# 347  2022      Delaware St. (MEAC)           False       DNP  DNP        DNP
# 348  2022  Mississippi Val. (SWAC)           False       DNP  DNP        DNP
# 349  2022   Lamar University (WAC)           False       DNP  DNP        DNP
#
# ...

# %%
end_stats.to_csv('NCAA_Final_Stats.csv', index=False)
